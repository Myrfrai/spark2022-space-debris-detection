# %% [markdown]
# # Pre-instaltion libraries

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8n.pt")
results = model.train(
    data= "../data/data.yaml",
    epochs= 1,
    imgsz= 1024,
    batch= 2,
    workers= 0,
    project= "../runs",
    name= "spark_test"
)
# Out:
# ...
# New https://pypi.org/project/ultralytics/8.4.66 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.60  Python-3.11.15 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce GTX 1650 Ti, 4096MiB)
# ...

# %%
model = YOLO("yolov8n.pt")
results = model.train(
    data= "../data/data.yaml",
    epochs= 10,
    imgsz= 1024,
    batch= 6,
    workers= 0,
    project= "../runs",
    name= "spark_10e_b4"
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.72 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.60  Python-3.11.15 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce GTX 1650 Ti, 4096MiB)
# ...

# %%
model = YOLO("../runs/runs/spark_10e_b4/weights/last.pt")

results = model.train(resume=True)
# Out:
# New https://pypi.org/project/ultralytics/8.4.72 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.60  Python-3.11.15 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce GTX 1650 Ti, 4096MiB)
# ...

# %%
model = YOLO("../runs/runs/spark_10e_b4/weights/best.pt")
results = model.train(
    data= "../data/data.yaml",
    epochs= 20,
    imgsz= 1024,
    batch= 6,
    workers= 0,
    project= "../runs",
    name= "spark_20e_continue"
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.75 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.60  Python-3.11.15 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce GTX 1650 Ti, 4096MiB)
# ...

# %%
model = YOLO("../runs/runs/spark_20e_continue/weights/last.pt")

results = model.train(resume=True)
# Out:
# New https://pypi.org/project/ultralytics/8.4.79 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.60  Python-3.11.15 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce GTX 1650 Ti, 4096MiB)
# ...
